# %%
import pandas as pd
import numpy as np

from pandas import json_normalize

from typing import Union
from io import StringIO

import yaml

# %%
config_path = '../config/params.yml'
config = yaml.load(open(config_path, encoding='utf-8'), Loader=yaml.FullLoader)

preproc = config['preprocessing']
evaluate = config['evaluate']

# %%
# df = pd.read_csv('D:/result_with_lik3.csv', sep=';')

# %%
df = pd.read_csv(preproc['raw_eval_data_path'], sep=',')
# df = pd.read_csv('D:/data_2022_full.csv', sep=',')
df[:5]
# Out:
#           Inn                                       balance_data   god
# 0  5027240707  {"КНД": "0710099", "ОКЕИ": 384, "СвНП": {"НПЮЛ...  2022
# 1  7729661379  {"КНД": "0710099", "ОКЕИ": 384, "СвНП": {"НПЮЛ...  2022
# 2  1001324088  {"КНД": "0710099", "ОКЕИ": 384, "СвНП": {"НПЮЛ...  2022
# 3  3433100233  {"КНД": "0710099", "ОКЕИ": 384, "СвНП": {"НПЮЛ...  2022
# 4  6143087579  {"КНД": "0710099", "ОКЕИ": 384, "СвНП": {"НПЮЛ...  2022

# %% [markdown]
# # Распаковка

# %%
df['balance_data'][0]
# Out:
# '{"КНД": "0710099", "ОКЕИ": 384, "СвНП": {"НПЮЛ": {"КПП": "502701001", "АдрМН": "140000, Московская обл, Люберцы г, Котельнический проезд, д. № 13, оф. 7", "ИННЮЛ": "5027240707", "НаимОрг": "Общество с ограниченной ответственностью \\"ЕВРОПРОДУКТ\\""}, "ОКПО": "02491568", "ОКФС": "16", "ОКОПФ": "12300", "ОКВЭД2": "10.84"}, "Баланс": {"ОКУД": "0710001", "Актив": {"ОбА": {"ДебЗад": {"СумОтч": 198477, "СумПрдщ": 157148, "СумПрдшв": 172958}, "Запасы": {"СумОтч": 219387, "СумПрдщ": 108123, "СумПрдшв": 74581}, "СумОтч": 498343, "ПрочОбА": {"СумОтч": 2920, "СумПрдщ": 6270, "СумПрдшв": 592}, "СумПрдщ": 322152, "ФинВлож": {"СумОтч": 50980, "СумПрдщ": 21137}, "ДенежнСр": {"СумОтч": 10756, "СумПрдщ": 6540, "СумПрдшв": 35417}, "СумПрдшв": 321281, "НДСПриобрЦен": {"СумОтч": 15823, "СумПрдщ": 22934, "СумПрдшв": 37732}}, "ВнеОбА": {"ОснСр": {"СумОтч": 892603, "СумПрдщ": 501532, "СумПрдшв": 194043}, "СумОтч": 892706, "СумПрдщ": 501611, "ФинВлож": {}, "ВлМатЦен": {}, "НематАкт": {"СумОтч": 12, "СумПрдщ": 12, "СумПрдшв": 12}, "СумПрдшв": 194064, "ОтлНалАкт": {"СумОтч": 91, "СумПрдщ": 67, "СумПрдшв": 9}, "РезИсслед": {}, "ПрочВнеОбА": {}}, "СумОтч": 1391049, "СумПрдщ": 823763, "СумПрдшв": 515345, "МатПоискАкт": {}, "НеМатПоискАкт": {}}, "Пассив": {"КапРез": {"СумОтч": 340521, "СумПрдщ": 105262, "СумПрдшв": 2412, "ДобКапитал": {}, "НераспПриб": {"СумОтч": 340511, "СумПрдщ": 105252, "СумПрдшв": 2402}, "РезКапитал": {}, "СобствАкции": {}, "ПереоцВнеОбА": {}, "УставКапитал": {"СумОтч": 10, "СумПрдщ": 10, "СумПрдшв": 10}}, "СумОтч": 1391049, "СумПрдщ": 823763, "СумПрдшв": 515345, "ЦелевФин": {"ПайФонд": {}, "ФондИмущ": {}, "РезервИнЦФ": {}, "ЦелевКапитал": {}, "ЦелевСредства": {}}, "ДолгосрОбяз": {"СумОтч": 409190, "СумПрдщ": 461546, "ОценОбяз": {}, "ПрочОбяз": {"СумОтч": 13944, "СумПрдщ": 3811}, "СумПрдшв": 100073, "ЗаемСредств": {"СумОтч": 394192, "СумПрдщ": 457588, "СумПрдшв": 99972}, "ОтложНалОбяз": {"СумОтч": 1054, "СумПрдщ": 147, "СумПрдшв": 102}}, "КраткосрОбяз": {"СумОтч": 641338, "СумПрдщ": 256955, "ОценОбяз": {}, "ПрочОбяз": {"СумПрдшв": 1}, "СумПрдшв": 412860, "ДоходБудущ": {}, "ЗаемСредств": {"СумОтч": 215158, "СумПрдщ": 22433, "СумПрдшв": 248565}, "КредитЗадолж": {"СумОтч": 426180, "СумПрдщ": 234522, "СумПрдшв": 164294}}}}, "Период": 34, "ФинРез": {"ОКУД": "0710002", "Выруч": {"СумОтч": 1643015}, "Прочее": {"СумОтч": 3430}, "НалПриб": {"СумОтч": -26011}, "ПроцУпл": {"СумОтч": 6333}, "ПрибПрод": {"СумОтч": 301149}, "КомРасход": {"СумОтч": 106873}, "ПроцПолуч": {"СумОтч": 483}, "ПрочДоход": {"СумОтч": 70957}, "СовФинРез": {"СумОтч": 235259}, "УпрРасход": {"СумОтч": 166057}, "ИзмНалОбяз": {}, "ПрочРасход": {"СумОтч": 108416}, "СебестПрод": {"СумОтч": 1068936}, "ТекНалПриб": {"СумОтч": 21666}, "ЧистПрибУб": {"СумОтч": 235259}, "ИзмНалАктив": {}, "ПостНалОбяз": {}, "ПрибУбДоНал": {"СумОтч": 257840}, "ДоходОтУчаст": {}, "ОтложНалПриб": {"СумОтч": -883}, "РезПрОпНеЧист": {}, "ВаловаяПрибыль": {"СумОтч": 574079}, "НалПрибОпНеЧист": {}, "РезПрцВОАНеЧист": {}}, "ЦелИсп": {"ОКУД": "0710003", "Поступило": {"Прочие": {}, "ПрибПредДеят": {}, "ВзносЦелПоступ": {}}, "ОстатКонОтч": {}, "ОстатНачОтч": {}, "Использовано": {"Прочие": {}, "ЦелМер": {}, "ПриобОСИн": {}, "СодеожОрг": {}}}, "ДатаДок": "20.01.2023", "НомКорр": 0, "ПрАудит": true, "СвАудит": {"АудитОрг": {"ОГРН": "1217700020361", "ИННЮЛ": "7726472630", "НаимОрг": "ООО АК \\"АСПЕКТ-АУДИТ\\""}}, "ВерсФорм": "5.08", "ОтчетГод": 2022, "Подписант": {"ФИО": {"Имя": "Маргарита", "Фамилия": "Дыдыкина", "Отчество": "Владимировна"}, "ПрПодп": "2", "СвПред": {"НаимДок": "Доверенность №ДЕВ-061022-57 от 06.10.2022 г."}}, "ДвижениеДен": {"ОКУД": "0710005", "ИнвОпер": {"Платеж": {"СумОтч": 241736, "ПроцДолгОб": {}, "ПрочПлатеж": {}, "ПриобрАкцДр": {}, "ПриобрДолгЦБ": {}, "ПриобрВнАктив": {"СумОтч": 241736}}, "Поступ": {"СумОтч": 3076, "ДивПроц": {"СумОтч": 3076}, "ПродАкцДр": {}, "ПрочПоступ": {}, "ВозврЗаймЦБ": {}, "ПродВнАктив": {}}, "СальдоИнв": {"СумОтч": -238660}}, "ТекОпер": {"Платеж": {"СумОтч": 1654892, ...

# %%
def safe_json_loads(x: str) -> Union[dict, None]:
    """
    Преобразование json-данных в соответствующий объект python
    :param x: путь до файла со словарем
    :return: преобразованный объект python
    :return: None
    """
    try:
        return json.loads(x)
    except json.JSONDecodeError:
        return None

# %%
df[preproc['unpack_col_name']] = df[preproc['unpack_col_name']].apply(
    safe_json_loads)
df[preproc['unpack_col_name']][0]
# Out:
# {'КНД': '0710099',
#  'ОКЕИ': 384,
#  'СвНП': {'НПЮЛ': {'КПП': '502701001',
#    'АдрМН': '140000, Московская обл, Люберцы г, Котельнический проезд, д. № 13, оф. 7',
#    'ИННЮЛ': '5027240707',
#    'НаимОрг': 'Общество с ограниченной ответственностью "ЕВРОПРОДУКТ"'},
#   'ОКПО': '02491568',
#   'ОКФС': '16',
#   'ОКОПФ': '12300',
#   'ОКВЭД2': '10.84'},
#  'Баланс': {'ОКУД': '0710001',
#   'Актив': {'ОбА': {'ДебЗад': {'СумОтч': 198477,
#      'СумПрдщ': 157148,
#      'СумПрдшв': 172958},
#     'Запасы': {'СумОтч': 219387, 'СумПрдщ': 108123, 'СумПрдшв': 74581},
#     'СумОтч': 498343,
#     'ПрочОбА': {'СумОтч': 2920, 'СумПрдщ': 6270, 'СумПрдшв': 592},
#     'СумПрдщ': 322152,
#     'ФинВлож': {'СумОтч': 50980, 'СумПрдщ': 21137},
#     'ДенежнСр': {'СумОтч': 10756, 'СумПрдщ': 6540, 'СумПрдшв': 35417},
#     'СумПрдшв': 321281,
#     'НДСПриобрЦен': {'СумОтч': 15823, 'СумПрдщ': 22934, 'СумПрдшв': 37732}},
#    'ВнеОбА': {'ОснСр': {'СумОтч': 892603,
#      'СумПрдщ': 501532,
#      'СумПрдшв': 194043},
#     'СумОтч': 892706,
#     'СумПрдщ': 501611,
#     'ФинВлож': {},
#     'ВлМатЦен': {},
#     'НематАкт': {'СумОтч': 12, 'СумПрдщ': 12, 'СумПрдшв': 12},
#     'СумПрдшв': 194064,
#     'ОтлНалАкт': {'СумОтч': 91, 'СумПрдщ': 67, 'СумПрдшв': 9},
#     'РезИсслед': {},
#     'ПрочВнеОбА': {}},
#    'СумОтч': 1391049,
#    'СумПрдщ': 823763,
#    'СумПрдшв': 515345,
#    'МатПоискАкт': {},
#    'НеМатПоискАкт': {}},
#   'Пассив': {'КапРез': {'СумОтч': 340521,
#     'СумПрдщ': 105262,
#     'СумПрдшв': 2412,
#     'ДобКапитал': {},
#     'НераспПриб': {'СумОтч': 340511, 'СумПрдщ': 105252, 'СумПрдшв': 2402},
#     'РезКапитал': {},
#     'СобствАкции': {},
#     'ПереоцВнеОбА': {},
#     'УставКапитал': {'СумОтч': 10, 'СумПрдщ': 10, 'СумПрдшв': 10}},
#    'СумОтч': 1391049,
#    'СумПрдщ': 823763,
#    'СумПрдшв': 515345,
#    'ЦелевФин': {'ПайФонд': {},
#     'ФондИмущ': {},
#     'РезервИнЦФ': {},
#     'ЦелевКапитал': {},
#     'ЦелевСредства': {}},
#    'ДолгосрОбяз': {'СумОтч': 409190,
#     'СумПрдщ': 461546,
#     'ОценОбяз': {},
#     'ПрочОбяз': {'СумОтч': 13944, 'СумПрдщ': 3811},
#     'СумПрдшв': 100073,
#     'ЗаемСредств': {'СумОтч': 394192, 'СумПрдщ': 457588, 'СумПрдшв': 99972},
#     'ОтложНалОбяз': {'СумОтч': 1054, 'СумПрдщ': 147, 'СумПрдшв': 102}},
#    'КраткосрОбяз': {'СумОтч': 641338,
#     'СумПрдщ': 256955,
#     'ОценОбяз': {},
#     'ПрочОбяз': {'СумПрдшв': 1},
#     'СумПрдшв': 412860,
#     'ДоходБудущ': {},
#     'ЗаемСредств': {'СумОтч': 215158, 'СумПрдщ': 22433, 'СумПрдшв': 248565},
#     'КредитЗадолж': {'СумОтч': 426180,
#      'СумПрдщ': 234522,
#      'СумПрдшв': 164294}}}},
#  'Период': 34,
#  'ФинРез': {'ОКУД': '0710002',
#   'Выруч': {'СумОтч': 1643015},
#   'Прочее': {'СумОтч': 3430},
#   'НалПриб': {'СумОтч': -26011},
#   'ПроцУпл': {'СумОтч': 6333},
#   'ПрибПрод': {'СумОтч': 301149},
#   'КомРасход': {'СумОтч': 106873},
#   'ПроцПолуч': {'СумОтч': 483},
#   'ПрочДоход': {'СумОтч': 70957},
#   'СовФинРез': {'СумОтч': 235259},
#   'УпрРасход': {'СумОтч': 166057},
#   'ИзмНалОбяз': {},
#   'ПрочРасход': {'СумОтч': 108416},
#   'СебестПрод': {'СумОтч': 1068936},
#   'ТекНалПриб': {'СумОтч': 21666},
#   'ЧистПрибУб': {'СумОтч': 235259},
#   'ИзмНалАктив': {},
#   'ПостНалОбяз': {},
#   'ПрибУбДоНал': {'СумОтч': 257840},
#   'ДоходОтУчаст': {},
#   'ОтложНалПриб': {'СумОтч': -883},
#   'РезПрОпНеЧист': {},
#   'ВаловаяПрибыль': {'СумОтч': 574079},
#   'НалПрибОпНеЧист': {},
#   'РезПрцВОАНеЧист': {}},
#  'ЦелИсп': {'ОКУД': '0710003',
#   'Поступило': {'Прочие': {}, 'ПрибПредДеят': {}, 'ВзносЦелПоступ': {}},
#   'ОстатКонОтч': {},
#   'ОстатНачОтч': {},
#   'Использовано': {'Прочие': {},
#    'ЦелМер': {},
#    'ПриобОСИн': {},
#    'СодеожОрг': {}}},
#  'ДатаДок': '20.01.2023',
#  'НомКорр': 0,
#  'ПрАудит': True,
#  'СвАудит': {'АудитОрг': {'ОГРН': '1217700020361',
#    'ИННЮЛ': '7726472630',
#    'НаимОрг': 'ООО АК "АСПЕКТ-АУДИТ"'}},
#  'ВерсФорм': '5.08',
#  'ОтчетГод': 2022,
#  'Подписант': {'ФИО': {'Имя': 'Маргарита',
#    'Фамилия': 'Дыдыкина',
#    'Отчество': 'Владимировна'},
#   'ПрПодп': '2',
#   'СвПред': {'НаимДок': 'Доверенность №ДЕВ-061022-57 от 06.10.2022 г.'}},
#  'ДвижениеДен': {'ОКУД': '0710005',
#   'ИнвОпер': {'Платеж': {'СумОтч': 241736,
#     'ПроцДолгОб': {},
#     'ПрочПлатеж': {},
#     'ПриобрАкцДр': {},
#     'ПриобрДолгЦБ': {},
#     'ПриобрВнАктив': {'СумОтч': 241736}},
#    'Поступ': {'СумОтч': 3076,
#     'ДивПроц': {'СумОтч': 3076},
#     'ПродАкцДр': {},
#     'ПрочПоступ': {},
#     'ВозврЗаймЦБ': {},
#     'ПродВнАктив': {}},
#    'СальдоИнв': {'СумОтч': -238660}},
#   'ТекОпер': {'Платеж': {'СумОтч': 1654892,
#     'СумПред': 1056874,
#     'НалогПриб': {'СумОтч': 15500, 'СумПред': 17571},
#     'ПоставСМРУ': {'СумОтч': 1257857, 'СумПред': 862897},
#     'ПрочПлатеж': {'СумОтч': 94321, 'СумПред': 52066},
#     'ОплатТрудРаб': {'СумОтч': 266512, 'СумПред': 110151},
#     'ПроцДолгОбяз': {'СумОтч': 20702, 'СумПред': 14189}},
#    'Поступ': {'СумОтч': 1637650,
#     'СумПред': 867145,
#     'ПродПТРУ': {'СумОтч': 1557348, 'СумПред': 823893},
#     'ПрочПоступ': {'СумОтч': 80302, 'СумПред': 43252},
#     'АрЛицИнПлат': {},
#     'ПродФинВлож': {}},
#    'СальдоТек': {'СумОтч': -17242, 'СумПред': -189729}},
#   'ФинОпер': {'Платеж': {'СумОтч': 783441,
#     'СумПред': 2256,
#     'ВыкупАкц': {},
#     'УплДивИн': {'СумПред': 2256},
#     'ВыкВексКЗ': {'СумОтч': 264541},
#     'ПрочПлатеж': {'СумОтч': 518900}},
#    'Поступ': {'АкцДол': {},
#     'СумОтч': 1075368,
#     'СумПред': 184169,
#     'ВкладСоб': {},
#     'КредЗайм': {'СумОтч': 589408, 'СумПред': 184169},
#     'ОблВексДр': {},
#     'ПрочПоступ': {'СумОтч': 485960}},
#    'СальдоФин': {'СумОтч': 291927, 'СумПред': 181913}},
#   'ВлИзмКурс': {'СумОтч': -1966, 'СумПред': 76},
#   'ОстКонОтч': {'СумОтч': 61736, 'СумПред': 27677},
#   'ОстНачОтч': {'СумОтч': 27677, 'СумПред': 35417},
#   'СальдоОтч': {'СумОтч': 36025, 'СумПред': -7816}},
#  'ОтчетИзмКап': {'ОКУД': '0710004',
#   'Коррект': {'КапитВс': {'ДоКоррект': {'На31ДекПред': 105262,
#      'ИзмКапИнФакт': -2621,
#      'ИзмКапЧистПр': 105471,
#      'На31ДекПрПред': 2412},
#     'КорИспрОш': {'На31ДекПред': 0},
#     'КорИзмУчПол': {'На31ДекПред': -366, 'ИзмКапЧистПр': -366},
#     'ПослеКоррект': {'На31ДекПред': 104896,
#      'ИзмКапИнФакт': -2621,
#      'ИзмКапЧистПр': 105105,
#      'На31ДекПрПред': 2412}},
#    'ДрСтатКап': {'ДоКоррект': {'На31ДекПред': 0},
#     'КорИспрОш': {'На31ДекПред': 0},
#     'КорИзмУчПол': {'На31ДекПред': 0},
#     'ПослеКоррект': {'На31ДекПред': 0}},
#    'НераспПриб': {'ДоКоррект': {'На31ДекПред': 105252,
#      'ИзмКапИнФакт': -2621,
#      'ИзмКапЧистПр': 105471,
#      'На31ДекПрПред': 2402},
#     'КорИспрОш': {'На31ДекПред': 0},
#     'КорИзмУчПол': {'На31ДекПред': -366, 'ИзмКапЧистПр': -366},
#     'ПослеКоррект': {'На31ДекПред': 104886,
#      'ИзмКапИнФакт': -2621,
#      'ИзмКапЧистПр': 105105,
#      'На31ДекПрПред': 2402}}},
#   'ДвиженКап': {'ПредГод': {'Кап31дек': {'Итог': 105262,
#      'НераспПриб': 105252,
#      'УстКапитал': 10},
#     'ИзмДобавКап': {},
#     'УменКапитал': {'Убыток': {},
#      'Дивиденды': {'Итог': 2256, 'НераспПриб': 2256},
#      'УменКапВс': {'Итог': 2256, 'НераспПриб': 2256},
#      'ПереоцИмущ': {},
#      'УменНомАкц': {},
#      'РасхУменКап': {},
#      'УменКолАкций': {},
#      'Реорганизация': {}},
#     'ИзмРезервКап': {},
#     'УвеличКапитал': {'ЧистПриб': {'Итог': 105471, 'НераспПриб': 105471},
#      'ДохУвелКап': {},
#      'ПереоцИмущ': {},
#      'ДопВыпАкций': {},
#      'УвеличКапВс': {'Итог': 105471, 'НераспПриб': 105471},
#      'УвеличНомАкц': {},
#      'Реорганизация': {}}},
#    'ОтчетГод': {'Кап31дек': {'Итог': 340521,
#      'НераспПриб': 340511,
#      'УстКапитал': 10},
#     'ИзмДобавКап': {},
#     'УменКапитал': {'Убыток': {},
#      'Дивиденды': {},
#      'УменКапВс': {},
#      'ПереоцИмущ': {},
#      'УменНомАкц': {},
#      'РасхУменКап': {},
#      'УменКолАкций': {},
#      'Реорганизация': {}},
#     'ИзмРезервКап': {},
#     'УвеличКапитал': {'ЧистПриб': {'Итог': 235260, 'НераспПриб': 235260},
#      'ДохУвелКап': {},
#      'ПереоцИмущ': {},
#      'ДопВыпАкций': {},
#      'УвеличКапВс': {'Итог': 235260, 'НераспПриб': 235260},
#      'УвеличНомАкц': {},
#      'Реорганизация': {}}},
#    'Кап31ДекПред': {'Итог': 2412,
#     'ДобКапитал': 0,
#     'НераспПриб': 2402,
#     'РезКапитал': 0,
#     'УстКапитал': 10,
#     'СобВыкупАкц': 0}},
#   'ЧистАктив': {'На31ДекОтч': 340521,
#    'На31ДекПред': 105261,
#    'На31ДекПрПред': 2412}}}

# %%
def unpack_lvl_1(data: pd.DataFrame, column_name: str) -> pd.DataFrame:
    """
    Распаковка указанного столбца на один уровень
    :param data: датасет
    :param column_name: название столбца для распаковки
    :return: исходный датасет с распакованными признаками
    """

    if column_name not in data.columns:
        raise ValueError(f"Столбец '{column_name}' не найден в DataFrame")

    unpacked_data = data[column_name].apply(pd.Series)
    data = data.drop([column_name], axis=1)
    data = pd.concat([data, unpacked_data], axis=1)

    return data

# %%
df = unpack_lvl_1(df, column_name='balance_data')

# %% [markdown]
# Теперь в качестве признаков имеем разделы бухгалтерского отчета:

# %%
df
# Out:
#              Inn   god      КНД  ОКЕИ  \
# 0     5027240707  2022  0710099   384
# 1     7729661379  2022  0710099   384
# 2     1001324088  2022  0710099   384
# 3     3433100233  2022  0710099   384
# 4     6143087579  2022  0710099   384
# ...          ...   ...      ...   ...
# 9995  7709395337  2022  0710099   384
# 9996  2636211882  2022  0710099   384
# 9997  6683008451  2022  0710099   384
# 9998  5036051625  2022  0710099   384
# 9999  7734032778  2022  0710099   384
#
#                                                    СвНП  \
# 0     {'НПЮЛ': {'КПП': '502701001', 'АдрМН': '140000...
# 1     {'НПЮЛ': {'КПП': '772901001', 'АдрМН': '121471...
# 2     {'НПЮЛ': {'КПП': '100101001', 'АдрМН': '185007...
# 3     {'НПЮЛ': {'КПП': '343301001', 'АдрМН': '404485...
# 4     {'НПЮЛ': {'КПП': '614301001', 'АдрМН': '347360...
# ...                                                 ...
# 9995  {'НПЮЛ': {'КПП': '770201001', 'АдрМН': '129090...
# 9996  {'НПЮЛ': {'КПП': '263601001', 'АдрМН': '355035...
# 9997  {'НПЮЛ': {'КПП': '668301001', 'АдрМН': '624261...
# 9998  {'НПЮЛ': {'КПП': '503601001', 'АдрМН': '142100...
# 9999  {'НПЮЛ': {'КПП': '772801001', 'АдрМН': '643,11...
#
#                                                  Баланс  Период  \
# 0     {'ОКУД': '0710001', 'Актив': {'ОбА': {'ДебЗад'...      34
# 1     {'ОКУД': '0710001', 'Актив': {'ОбА': {'ДебЗад'...      34
# 2     {'ОКУД': '0710001', 'Актив': {'ОбА': {'ДебЗад'...      34
# 3     {'ОКУД': '0710001', 'Актив': {'ОбА': {'ДебЗад'...      94
# 4     {'ОКУД': '0710001', 'Актив': {'ОбА': {'ДебЗад'...      94
# ...                                                 ...     ...
# 9995  {'ОКУД': '0710001', 'Актив': {'ОбА': {'ДебЗад'...      34
# 9996  {'ОКУД': '0710001', 'Актив': {'ОбА': {'ДебЗад'...      34
# 9997  {'ОКУД': '0710001', 'Актив': {'ОбА': {'ДебЗад'...      34
# 9998  {'ОКУД': '0710001', 'Актив': {'ОбА': {'ДебЗад'...      34
# 9999  {'ОКУД': '0710001', 'Актив': {'ОбА': {'ДебЗад'...      34
#
#                                                  ФинРез  \
# 0     {'ОКУД': '0710002', 'Выруч': {'СумОтч': 164301...
# 1     {'ОКУД': '0710002', 'Выруч': {'СумОтч': 13171}...
# 2     {'ОКУД': '0710002', 'Выруч': {'СумОтч': 153623...
# 3     {'ОКУД': '0710002', 'Выруч': {'СумОтч': 15962}...
# 4     {'ОКУД': '0710002', 'Выруч': {'СумОтч': 6719},...
# ...                                                 ...
# 9995  {'ОКУД': '0710002', 'Выруч': {'СумОтч': 158281...
# 9996  {'ОКУД': '0710002', 'Выруч': {'СумОтч': 193815...
# 9997  {'ОКУД': '0710002', 'Выруч': {'СумОтч': 23906,...
# 9998  {'ОКУД': '0710002', 'Выруч': {'СумОтч': 200434...
# 9999  {'ОКУД': '0710002', 'Выруч': {'СумОтч': 157360...
#
#                                                  ЦелИсп     ДатаДок  НомКорр  \
# 0     {'ОКУД': '0710003', 'Поступило': {'Прочие': {}...  20.01.2023        0
# 1     {'ОКУД': '0710003', 'Поступило': {'Прочие': {}...  20.01.2023        0
# 2     {'ОКУД': '0710003', 'Поступило': {'Прочие': {}...  20.01.2023        0
# 3     {'ОКУД': '0710003', 'Поступило': {'Прочие': {}...  07.06.2022        0
# 4     {'ОКУД': '0710003', 'Поступило': {'Прочие': {}...  08.06.2022        1
# ...                                                 ...         ...      ...
# 9995  {'ОКУД': '0710003', 'Поступило': {'Прочие': {}...  21.03.2023        1
# 9996  {'ОКУД': '0710003', 'Поступило': {'Прочие': {}...  14.03.2023        0
# 9997  {'ОКУД': '0710003', 'Поступило': {'Прочие': {}...  21.03.2023        0
# 9998  {'ОКУД': '0710003', 'Поступило': {'Прочие': {}...  21.03.2023        0
# 9999  {'ОКУД': '0710003', 'Поступило': {'Прочие': {}...  21.03.2023        0
#
#       ПрАудит                                            СвАудит ВерсФорм  \
# 0        True  {'АудитОрг': {'ОГРН': '1217700020361', 'ИННЮЛ'...     5.08
# 1       False  {'АудитОрг': {'ОГРН': '', 'ИННЮЛ': '', 'НаимОр...     5.08
# 2       False  {'АудитОрг': {'ОГРН': '', 'ИННЮЛ': '', 'НаимОр...     5.08
# 3       False  {'АудитОрг': {'ОГРН': '', 'ИННЮЛ': '', 'НаимОр...     5.08
# 4        True  {'АудитОрг': {'ОГРН': '', 'ИННЮЛ': '', 'НаимОр...     5.08
# ...       ...                                                ...      ...
# 9995    False  {'АудитОрг': {'ОГРН': '', 'ИННЮЛ': '', 'НаимОр...     5.08
# 9996     True  {'АудитОрг': {'ОГРН': '1142651024603', 'ИННЮЛ'...     5.08
# 9997     True  {'АудитОрг': {'ОГРН': '1026605409270', 'ИННЮЛ'...     5.08
# 9998     True  {'АудитОрг': {'ОГРН': '5087746433495', 'ИННЮЛ'...     5.08
# 9999    False  {'АудитОрг': {'ОГРН': '', 'ИННЮЛ': '', 'НаимОр...     5.08
#
#       ОтчетГод                                          Подписант  \
# 0         2022  {'ФИО': {'Имя': 'Маргарита', 'Фамилия': 'Дыдык...
# 1         2022  {'ФИО': {'Имя': 'Нилотпаул', 'Фамилия': 'Майти...
# 2         2022  {'ФИО': {'Имя': 'Андрей', 'Фамилия': 'Микитенк...
# 3         2022  {'ФИО': {'Имя': 'Артем', 'Фамилия': 'Устимский...
# 4         2022  {'ФИО': {'Имя': 'Антон', 'Фамилия': 'Калайков'...
# ...        ...                                                ...
# 9995      2022  {'ФИО': {'Имя': 'Денис', 'Фамилия': 'Рыбалкин'...
# 9996      2022  {'ФИО': {'Имя': 'Павел', 'Фамилия': 'Арустамян...
# 9997      2022  {'ФИО': {'Имя': 'Инна', 'Фамилия': 'Толченова'...
# 9998      2022  {'ФИО': {'Имя': 'Дарья', 'Фамилия': 'Приймак',...
# 9999      2022  {'ФИО': {'Имя': 'СЕРГЕЙ', 'Фамилия': 'ПЛАТОНОВ...
#
#                                             ДвижениеДен  \
# 0     {'ОКУД': '0710005', 'ИнвОпер': {'Платеж': {'Су...
# 1     {'ОКУД': '0710005', 'ИнвОпер': {'Платеж': {'Пр...
# 2     {'ОКУД': '0710005', 'ИнвОпер': {'Платеж': {'Пр...
# 3     {'ОКУД': '0710005', 'ИнвОпер': {'Платеж': {'Су...
# 4     {'ОКУД': '0710005', 'ИнвОпер': {'Платеж': {'Пр...
# ...                                                 ...
# 9995  {'ОКУД': '0710005', 'ИнвОпер': {'Платеж': {'Су...
# 9996  {'ОКУД': '0710005', 'ИнвОпер': {'Платеж': {'Су...
# 9997  {'ОКУД': '0710005', 'ИнвОпер': {'Платеж': {'Су...
# 9998  {'ОКУД': '0710005', 'ИнвОпер': {'Платеж': {'Су...
# 9999  {'ОКУД': '0710005', 'ИнвОпер': {'Платеж': {'Пр...
#
#                                             ОтчетИзмКап
# 0     {'ОКУД': '0710004', 'Коррект': {'КапитВс': {'Д...
# 1     {'ОКУД': '0710004', 'Коррект': {'КапитВс': {'Д...
# 2     {'ОКУД': '0710004', 'Коррект': {'КапитВс': {'Д...
# 3     {'ОКУД': '0710004', 'Коррект': {'КапитВс': {'Д...
# 4     {'ОКУД': '0710004', 'Коррект': {'КапитВс': {'Д...
# ...                                                 ...
# 9995  {'ОКУД': '0710004', 'Коррект': {'КапитВс': {'Д...
# 9996  {'ОКУД': '0710004', 'Коррект': {'КапитВс': {'Д...
# 9997  {'ОКУД': '0710004', 'Коррект': {'КапитВс': {'Д...
# 9998  {'ОКУД': '0710004', 'Коррект': {'КапитВс': {'Д...
# 9999  {'ОКУД': '0710004', 'Коррект': {'КапитВс': {'Д...
#
# [10000 rows x 18 columns]

# %% [markdown]
# Распаковка на 1 уровень нужна, чтобы сразу отсеять разделы, с которыми мы не будем работать.
# Оставим основные разделы:
# - Баланс - бухгалтерский баланс
# - ФинРез - финансовые результаты
# - ОтчетИзмКап - отчет об изменениях капитала

# %%
def drop_columns(data: pd.DataFrame, columns_to_drop: list) -> pd.DataFrame:
    """
    Удаление столбцов из DataFrame, если они существуют. 
    :param data: датасет
    :param columns_to_drop: список столбцов для удаления
    :return: датасет 
    """

    missing_columns = [
        col for col in columns_to_drop if col not in data.columns
    ]
    if missing_columns:
        print(
            f"Следующих столбцов не существует в датасете: {missing_columns}")
    return data.drop(
        columns=[col for col in columns_to_drop if col in data.columns],
        errors='ignore')

# %%
df = drop_columns(df, preproc['drop_sections'])

# %%
df[:5]
# Out:
#           Inn   god      КНД  ОКЕИ  \
# 0  5027240707  2022  0710099   384
# 1  7729661379  2022  0710099   384
# 2  1001324088  2022  0710099   384
# 3  3433100233  2022  0710099   384
# 4  6143087579  2022  0710099   384
#
#                                               Баланс  Период  \
# 0  {'ОКУД': '0710001', 'Актив': {'ОбА': {'ДебЗад'...      34
# 1  {'ОКУД': '0710001', 'Актив': {'ОбА': {'ДебЗад'...      34
# 2  {'ОКУД': '0710001', 'Актив': {'ОбА': {'ДебЗад'...      34
# 3  {'ОКУД': '0710001', 'Актив': {'ОбА': {'ДебЗад'...      94
# 4  {'ОКУД': '0710001', 'Актив': {'ОбА': {'ДебЗад'...      94
#
#                                               ФинРез     ДатаДок  НомКорр  \
# 0  {'ОКУД': '0710002', 'Выруч': {'СумОтч': 164301...  20.01.2023        0
# 1  {'ОКУД': '0710002', 'Выруч': {'СумОтч': 13171}...  20.01.2023        0
# 2  {'ОКУД': '0710002', 'Выруч': {'СумОтч': 153623...  20.01.2023        0
# 3  {'ОКУД': '0710002', 'Выруч': {'СумОтч': 15962}...  07.06.2022        0
# 4  {'ОКУД': '0710002', 'Выруч': {'СумОтч': 6719},...  08.06.2022        1
#
#    ПрАудит ВерсФорм  ОтчетГод  \
# 0     True     5.08      2022
# 1    False     5.08      2022
# 2    False     5.08      2022
# 3    False     5.08      2022
# 4     True     5.08      2022
#
#                                          ОтчетИзмКап
# 0  {'ОКУД': '0710004', 'Коррект': {'КапитВс': {'Д...
# 1  {'ОКУД': '0710004', 'Коррект': {'КапитВс': {'Д...
# 2  {'ОКУД': '0710004', 'Коррект': {'КапитВс': {'Д...
# 3  {'ОКУД': '0710004', 'Коррект': {'КапитВс': {'Д...
# 4  {'ОКУД': '0710004', 'Коррект': {'КапитВс': {'Д...

# %%
def unpack_columns(data: pd.DataFrame) -> pd.DataFrame:
    """
    Распаковка многоуровневых признаков
    :param data: датасет
    :return: датасет
    """
    for col in data.columns:
        if isinstance(data[col].iloc[0], dict):
            unpacked = pd.json_normalize(data[col])
            data.drop(columns=[col], inplace=True)
            data = pd.concat([data, unpacked], axis=1)
    return data

# %%
df = unpack_columns(df)
df
# Out:
#              Inn   god      КНД  ОКЕИ  Период     ДатаДок  НомКорр  ПрАудит  \
# 0     5027240707  2022  0710099   384      34  20.01.2023        0     True
# 1     7729661379  2022  0710099   384      34  20.01.2023        0    False
# 2     1001324088  2022  0710099   384      34  20.01.2023        0    False
# 3     3433100233  2022  0710099   384      94  07.06.2022        0    False
# 4     6143087579  2022  0710099   384      94  08.06.2022        1     True
# ...          ...   ...      ...   ...     ...         ...      ...      ...
# 9995  7709395337  2022  0710099   384      34  21.03.2023        1    False
# 9996  2636211882  2022  0710099   384      34  14.03.2023        0     True
# 9997  6683008451  2022  0710099   384      34  21.03.2023        0     True
# 9998  5036051625  2022  0710099   384      34  21.03.2023        0     True
# 9999  7734032778  2022  0710099   384      34  21.03.2023        0    False
#
#      ВерсФорм  ОтчетГод  ... ДвиженКап.ПредГод.ИзмДобавКап.РезКапитал  \
# 0        5.08      2022  ...                                      NaN
# 1        5.08      2022  ...                                      NaN
# 2        5.08      2022  ...                                      NaN
# 3        5.08      2022  ...                                      NaN
# 4        5.08      2022  ...                                      NaN
# ...       ...       ...  ...                                      ...
# 9995     5.08      2022  ...                                      NaN
# 9996     5.08      2022  ...                                      NaN
# 9997     5.08      2022  ...                                      NaN
# 9998     5.08      2022  ...                                      NaN
# 9999     5.08      2022  ...                                      NaN
#
#       ДвиженКап.ОтчетГод.ИзмДобавКап.РезКапитал  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 9995                                        NaN
# 9996                                        NaN
# 9997                                        NaN
# 9998                                        NaN
# 9999                                        NaN
#
#       ДвиженКап.ОтчетГод.УменКапитал.УменНомАкц.НераспПриб  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997                                                NaN
# 9998                                                NaN
# 9999                                                NaN
#
#       ДвиженКап.ОтчетГод.УменКапитал.Реорганизация.СобВыкупАкц  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997                                                NaN
# 9998                                                NaN
# 9999                                                NaN
#
#       ДвиженКап.ПредГод.УменКапитал.УменНомАкц.НераспПриб  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997                                                NaN
# 9998                                                NaN
# 9999                                                NaN
#
#       ДвиженКап.ПредГод.УвеличКапитал.УвеличНомАкц.СобВыкупАкц  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997                                                NaN
# 9998                                                NaN
# 9999                                                NaN
#
#       ДвиженКап.ПредГод.УменКапитал.УменКолАкций.НераспПриб  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997                                                NaN
# 9998                                                NaN
# 9999                                                NaN
#
#       ДвиженКап.ОтчетГод.УменКапитал.УменНомАкц.ДобКапитал  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997                                                NaN
# 9998                                                NaN
# 9999                                                NaN
#
#       ДвиженКап.ПредГод.УвеличКапитал.УвеличНомАкц.НераспПриб  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997                                                NaN
# 9998                                                NaN
# 9999                                                NaN
#
#       ДвиженКап.ПредГод.УменКапитал.Реорганизация.СобВыкупАкц
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997                                                NaN
# 9998                                                NaN
# 9999                                                NaN
#
# [10000 rows x 429 columns]

# %% [markdown]
# # Удаление и редактирование признаков

# %% [markdown]
# Удалим столбцы с большим кол-вом пропусков:

# %%
def remove_columns_with_gaps(data: pd.DataFrame,
                             threshold: float) -> Union[pd.DataFrame, list]:
    """
    Удаление столбцов, где кол-во пропусков превышает заданный порог
    :param data: датасет
    :param threshold: пороговая доля пропусков
    :return: датасет
    :return: список удаленных столбцов
    """
    total_rows = data.shape[0]
    missing_threshold = total_rows * threshold
    columns_to_drop = data.columns[
        data.isnull().sum() > missing_threshold].tolist()

    data.drop(columns=columns_to_drop, inplace=True)

    return data, columns_to_drop

# %%
df, drops = remove_columns_with_gaps(df, preproc['threshold'])

# %%
preproc['threshold']
# Out:
# 0.35

# %%
print(f"Удалено столбцов: {len(drops)}")
print(f"Удаленные столбцы: {drops}")
# Out:
# Удалено столбцов: 314
# Удаленные столбцы: ['Актив.ОбА.ФинВлож.СумОтч', 'Актив.ОбА.ФинВлож.СумПрдщ', 'Актив.ОбА.НДСПриобрЦен.СумОтч', 'Актив.ОбА.НДСПриобрЦен.СумПрдщ', 'Актив.ОбА.НДСПриобрЦен.СумПрдшв', 'Актив.ВнеОбА.НематАкт.СумОтч', 'Актив.ВнеОбА.НематАкт.СумПрдщ', 'Актив.ВнеОбА.НематАкт.СумПрдшв', 'Актив.ВнеОбА.ОтлНалАкт.СумОтч', 'Актив.ВнеОбА.ОтлНалАкт.СумПрдщ', 'Актив.ВнеОбА.ОтлНалАкт.СумПрдшв', 'Пассив.ДолгосрОбяз.ПрочОбяз.СумОтч', 'Пассив.ДолгосрОбяз.ПрочОбяз.СумПрдщ', 'Пассив.ДолгосрОбяз.ЗаемСредств.СумОтч', 'Пассив.ДолгосрОбяз.ЗаемСредств.СумПрдщ', 'Пассив.ДолгосрОбяз.ЗаемСредств.СумПрдшв', 'Пассив.ДолгосрОбяз.ОтложНалОбяз.СумПрдщ', 'Пассив.ДолгосрОбяз.ОтложНалОбяз.СумПрдшв', 'Пассив.КраткосрОбяз.ПрочОбяз.СумПрдшв', 'Пассив.КраткосрОбяз.ЗаемСредств.СумОтч', 'Пассив.КраткосрОбяз.ЗаемСредств.СумПрдщ', 'Пассив.КраткосрОбяз.ЗаемСредств.СумПрдшв', 'Актив.ОбА.ФинВлож.СумПрдшв', 'Пассив.КапРез.ДобКапитал.СумОтч', 'Пассив.КапРез.ДобКапитал.СумПрдщ', 'Пассив.КапРез.ДобКапитал.СумПрдшв', 'Пассив.КраткосрОбяз.ОценОбяз.СумОтч', 'Пассив.КраткосрОбяз.ОценОбяз.СумПрдщ', 'Пассив.КраткосрОбяз.ОценОбяз.СумПрдшв', 'Актив.ВнеОбА.ФинВлож.СумОтч', 'Актив.ВнеОбА.ФинВлож.СумПрдщ', 'Актив.ВнеОбА.ФинВлож.СумПрдшв', 'Актив.ВнеОбА.ВлМатЦен.СумОтч', 'Актив.ОбА.ДебЗад.СумПред', 'Актив.ОбА.Запасы.СумПред', 'Актив.ОбА.ПрочОбА.СумПред', 'Актив.ВнеОбА.ПрочВнеОбА.СумПред', 'Пассив.КраткосрОбяз.ПрочОбяз.СумОтч', 'Пассив.КраткосрОбяз.ПрочОбяз.СумПрдщ', 'Пассив.КраткосрОбяз.ПрочОбяз.СумПред', 'Пассив.КраткосрОбяз.КредитЗадолж.СумПред', 'Актив.ОбА.ДебЗад.Пояснения', 'Актив.ОбА.Запасы.Пояснения', 'Актив.ОбА.ФинВлож.Пояснения', 'Актив.ОбА.ДенежнСр.СумПред', 'Актив.ОбА.НДСПриобрЦен.СумПред', 'Актив.ВнеОбА.ОснСр.СумПред', 'Актив.ВнеОбА.ОснСр.Пояснения', 'Актив.ВнеОбА.ФинВлож.Пояснения', 'Актив.ВнеОбА.ВлМатЦен.СумПрдщ', 'Актив.ВнеОбА.НематАкт.СумПред', 'Актив.ВнеОбА.НематАкт.Пояснения', 'Актив.ВнеОбА.ПрочВнеОбА.СумОтч', 'Актив.ВнеОбА.ПрочВнеОбА.СумПрдщ', 'Актив.ВнеОбА.ПрочВнеОбА.СумПрдшв', 'Пассив.КапРез.РезКапитал.СумОтч', 'Пассив.КапРез.РезКапитал.СумПрдщ', 'Пассив.КапРез.РезКапитал.СумПрдшв', 'Пассив.КапРез.ПереоцВнеОбА.СумОтч', 'Пассив.КапРез.ПереоцВнеОбА.СумПрдщ', 'Пассив.КапРез.ПереоцВнеОбА.СумПрдшв', 'Пассив.ДолгосрОбяз.ПрочОбяз.СумПред', 'Пассив.ДолгосрОбяз.ПрочОбяз.СумПрдшв', 'Пассив.КраткосрОбяз.ЗаемСредств.СумПред', 'Пассив.КраткосрОбяз.ЗаемСредств.Пояснения', 'Пассив.КраткосрОбяз.КредитЗадолж.Пояснения', 'Пассив.КраткосрОбяз.ДоходБудущ.СумОтч', 'Пассив.КраткосрОбяз.ДоходБудущ.СумПрдщ', 'Пассив.КраткосрОбяз.ДоходБудущ.СумПрдшв', 'Пассив.ДолгосрОбяз.ЗаемСредств.СумПред', 'Пассив.КраткосрОбяз.ОценОбяз.СумПред', 'Актив.ОбА.ПрочОбА.Пояснения', 'Актив.ОбА.ФинВлож.СумПред', 'Актив.ОбА.ДенежнСр.Пояснения', 'Пассив.КапРез.НераспПриб.Пояснения', 'Пассив.ДолгосрОбяз.ЗаемСредств.Пояснения', 'Актив.ВнеОбА.РезИсслед.СумОтч', 'Актив.ВнеОбА.РезИсслед.СумПрдщ', 'Актив.ВнеОбА.РезИсслед.СумПрдшв', 'Актив.ВнеОбА.ОтлНалАкт.Пояснения', 'Пассив.КапРез.Пояснения', 'Пассив.КапРез.ДобКапитал.Пояснения', 'Пассив.КапРез.УставКапитал.Пояснения', 'Пассив.ДолгосрОбяз.ОтложНалОбяз.Пояснения', 'Пассив.КраткосрОбяз.ОценОбяз.Пояснения', 'Актив.ВнеОбА.ФинВлож.СумПред', 'Пассив.ДолгосрОбяз.ПрочОбяз.Пояснения', 'Пассив.ДолгосрОбяз.ОценОбяз.СумОтч', 'Пассив.ДолгосрОбяз.ОценОбяз.СумПрдщ', 'Пассив.ДолгосрОбяз.ОценОбяз.СумПрдшв', 'Актив.ВнеОбА.ВлМатЦен.СумПрдшв', 'Актив.ВнеОбА.ВлМатЦен.Пояснения', 'Пассив.КраткосрОбяз.ПрочОбяз.Пояснения', 'Актив.ВнеОбА.ПрочВнеОбА.Пояснения', 'Актив.ВнеОбА.ОтлНалАкт.СумПред', 'Пассив.ДолгосрОбяз.ОтложНалОбяз.СумПред', 'Пассив.КапРез.СобствАкции.СумПрдщ', 'Актив.ВнеОбА.ВлМатЦен.СумПред', 'Актив.ВнеОбА.РезИсслед.СумПред', 'Пассив.КапРез.РезКапитал.СумПред', 'Пассив.КапРез.ПереоцВнеОбА.СумПред', 'Пассив.КраткосрОбяз.ДоходБудущ.СумПред', 'Актив.ВнеОбА.РезИсслед.Пояснения', 'Пассив.КраткосрОбяз.ДоходБудущ.Пояснения', 'Пассив.ДолгосрОбяз.ОценОбяз.Пояснения', 'Пассив.КапРез.НераспПриб.СумПред', 'Пассив.КапРез.УставКапитал.СумПред', 'Пассив.КапРез.СобствАкции.СумОтч', 'Пассив.КапРез.РезКап ...

# %%
df.shape
# Out:
# (10000, 115)

# %% [markdown]
# Некоторые из оставшихся признаков также можно удалить (по ключевому слову):

# %%
def remove_columns_with_keyword(data: pd.DataFrame,
                                list_keywords: [list, str]) -> pd.DataFrame:
    """
    Удаление столбцов, содержащих в названии ключевое слово
    :param data: датасет
    :param keyword: список ключевых слов
    :return: датасет
    """
    if isinstance(list_keywords, str):
        list_keywords = [list_keywords]
    columns_to_drop = [
        col for col in data.columns
        if any(keyword.lower() in col.lower() for keyword in list_keywords)
    ]
    data.drop(columns=columns_to_drop, inplace=True)
    return data

# %%
df = remove_columns_with_keyword(df, preproc['drop_by_keyword'][0])

# %%
preproc['drop_by_keyword'][0]
# Out:
# 'коррект.'

# %%
df.shape
# Out:
# (10000, 95)

# %% [markdown]
# Проанализируем некоторые оставшиеся признаки, удалим лишнее:

# %%
df['ВерсФорм'].value_counts()
# Out:
# ВерсФорм
# 5.08    10000
# Name: count, dtype: int64

# %%
def missing_values(data: pd.DataFrame):
    """
    Подсчет и вывод пропусков в столбцах
    :param data: датасет
    """
    columns_with_mv = data.columns[data.isnull().any()]
    for column in columns_with_mv:
        print(
            f'{column}: {round(data[column].isna().sum() / data.shape[0]*100, 1)}% пропусков'
        )

# %%
# Посмотрим сколько плохо заполненных признаков содержит версия 5.03 
# Не всегда она есть в данных
filtr = df[df['ВерсФорм'] == '5.03']
missing_values(filtr)

# %% [markdown]
# У компаний сдающих отчет по версии 5.03 почти все признаки не заполнены - эти компании можно удалить

# %%
df = df.drop(df[df['ВерсФорм'] == '5.03'].index)

# %%
df['Период'].value_counts()
# Out:
# Период
# 34    9855
# 94     145
# Name: count, dtype: int64

# %%
df['god'].value_counts()
# Out:
# god
# 2022    10000
# Name: count, dtype: int64

# %%
df['ОтчетГод'].value_counts()
# Out:
# ОтчетГод
# 2022    10000
# Name: count, dtype: int64

# %%
df = drop_columns(df, preproc['drop_columns'])

# %%
def replace_values(data: pd.DataFrame, change_columns: dict) -> pd.DataFrame:
    """
    Замена значений в датасете
    :param data: датасет
    :param change_columns: словарь со старыми и новыми значениями
    :return: датасет
    """
    for old_str, new_str in change_columns.items():
        data.columns = data.columns.str.replace(old_str, new_str)
    return data

# %%
replace_values(data=df, change_columns=preproc['rename_columns'])
# Out:
#       ПрАудит  Актив_ОбА_ДебЗад_Отч  Актив_ОбА_ДебЗад_Пред  \
# 0        True              198477.0               157148.0
# 1       False              134095.0               138838.0
# 2       False                9569.0                 6316.0
# 3       False               91588.0               104941.0
# 4        True             1381628.0               216102.0
# ...       ...                   ...                    ...
# 9995    False               21240.0                15689.0
# 9996     True              233137.0               244945.0
# 9997     True                4762.0                 8036.0
# 9998     True               97573.0               138679.0
# 9999    False                9868.0                12038.0
#
#       Актив_ОбА_ДебЗад_ПредПред  Актив_ОбА_Запасы_Отч  Актив_ОбА_Запасы_Пред  \
# 0                      172958.0                219387               108123.0
# 1                      125797.0                 27525                33953.0
# 2                           NaN                  4145                  131.0
# 3                       93807.0                  4249                 4386.0
# 4                      217196.0                    39                    NaN
# ...                         ...                   ...                    ...
# 9995                    15949.0                     6                    6.0
# 9996                   326561.0                814115               747396.0
# 9997                     7119.0                 13125                 9252.0
# 9998                   337588.0                  2510                26341.0
# 9999                    10773.0                 37663                42052.0
#
#       Актив_ОбА_Запасы_ПредПред  Актив_ОбА_Отч  Актив_ОбА_ПрочОбА_Отч  \
# 0                       74581.0         498343                   2920
# 1                       34039.0         229725                   8407
# 2                           NaN          19589                   1882
# 3                      178013.0          95934                     53
# 4                          21.0        1586667                     74
# ...                         ...            ...                    ...
# 9995                     2548.0          58584                    335
# 9996                   497202.0        1130222                    323
# 9997                     4112.0          37110                    262
# 9998                    30525.0         650547                   2587
# 9999                    48933.0         111411                    404
#
#       Актив_ОбА_ПрочОбА_Пред  ...  \
# 0                     6270.0  ...
# 1                    21565.0  ...
# 2                      760.0  ...
# 3                        NaN  ...
# 4                        NaN  ...
# ...                      ...  ...
# 9995                   342.0  ...
# 9996                   333.0  ...
# 9997                 29679.0  ...
# 9998                  2484.0  ...
# 9999                   282.0  ...
#
#       ДвиженКап_ОтчетГод_УвеличКапитал_УвеличКапВс_НераспПриб  \
# 0                                              235260.0
# 1                                                5949.0
# 2                                                6342.0
# 3                                               10431.0
# 4                                                   NaN
# ...                                                 ...
# 9995                                             6440.0
# 9996                                            10007.0
# 9997                                                NaN
# 9998                                            54662.0
# 9999                                            51411.0
#
#       ДвижКап_Итог_ПредПред  ДвиженКап_Кап31ДекПред_ДобКапитал  \
# 0                      2412                                  0
# 1                     91032                                  0
# 2                        10                                  0
# 3                   -953981                              40160
# 4                    -62163                                124
# ...                     ...                                ...
# 9995                  38872                              16274
# 9996                  19231                                  0
# 9997                 250718                             296000
# 9998                 387240                                  0
# 9999                  97798                              25922
#
#       ДвиженКап_Кап31ДекПред_НераспПриб  ДвиженКап_Кап31ДекПред_РезКапитал  \
# 0                                  2402                                  0
# 1                                 58282                                  0
# 2                                     0                                  0
# 3                               -994222                                  0
# 4                                -62297                                  0
# ...                                 ...                                ...
# 9995                              22588                                  0
# 9996                              19221                                  0
# 9997                             -67376                                  0
# 9998                             385240                                  0
# 9999                              71777                                  0
#
#       ДвиженКап_Кап31ДекПред_УстКапитал  ДвиженКап_Кап31ДекПред_СобВыкупАкц  \
# 0                                    10                                   0
# 1                                 32750                                   0
# 2                                    10                                   0
# 3                                    81                                   0
# 4                                    10                                   0
# ...                                 ...                                 ...
# 9995                                 10                                   0
# 9996                                 10                                   0
# 9997                              22094                                   0
# 9998                               2000                                   0
# 9999                                 99                                   0
#
#       ЧистАктив_Отч  ЧистАктив_Пред  ЧистАктив_ПредПред
# 0            340521          105261                2412
# 1             96885           90936               91032
# 2              6791             677                  10
# 3           -949173         -959604             -953981
# 4          -2485153          -54827              -62163
# ...             ...             ...                 ...
# 9995          48667           42227               38872
# 9996          36161           32424               19231
# 9997         319776          305706              250718
# 9998         365065          420531              387240
# 9999              0               0                   0
#
# [10000 rows x 83 columns]

# %% [markdown]
# Удалим по ключевому слову признаки, связанные с движением капитала (кроме столбцов с общими итогами, их мы переименовали ранее):

# %%
df = remove_columns_with_keyword(df, preproc['drop_by_keyword'][1])

# %%
df.shape
# Out:
# (10000, 66)

# %%
missing_values(df)
# Out:
# Актив_ОбА_ДебЗад_Отч: 0.1% пропусков
# Актив_ОбА_ДебЗад_Пред: 1.9% пропусков
# Актив_ОбА_ДебЗад_ПредПред: 5.3% пропусков
# Актив_ОбА_Запасы_Пред: 5.1% пропусков
# Актив_ОбА_Запасы_ПредПред: 9.6% пропусков
# Актив_ОбА_ПрочОбА_Пред: 8.7% пропусков
# Актив_ОбА_ПрочОбА_ПредПред: 17.4% пропусков
# Актив_ОбА_Пред: 1.6% пропусков
# Актив_ОбА_ДенежнСр_Отч: 1.7% пропусков
# Актив_ОбА_ДенежнСр_Пред: 3.1% пропусков
# Актив_ОбА_ДенежнСр_ПредПред: 6.4% пропусков
# Актив_ОбА_ПредПред: 4.6% пропусков
# Актив_ВнеОбА_ОснСр_Пред: 5.8% пропусков
# Актив_ВнеОбА_ОснСр_ПредПред: 12.7% пропусков
# Актив_ВнеОбА_Пред: 4.1% пропусков
# Актив_ВнеОбА_ПредПред: 10.2% пропусков
# Актив_Пред: 1.6% пропусков
# Актив_ПредПред: 4.6% пропусков
# Пассив_КапРез_Пред: 1.6% пропусков
# Пассив_КапРез_ПредПред: 4.7% пропусков
# Пассив_КапРез_НераспПриб_Отч: 0.1% пропусков
# Пассив_КапРез_НераспПриб_Пред: 1.8% пропусков
# Пассив_КапРез_НераспПриб_ПредПред: 5.5% пропусков
# Пассив_КапРез_УставКапитал_Отч: 0.8% пропусков
# Пассив_КапРез_УставКапитал_Пред: 2.4% пропусков
# Пассив_КапРез_УставКапитал_ПредПред: 5.4% пропусков
# Пассив_Пред: 1.6% пропусков
# Пассив_ПредПред: 4.6% пропусков
# Пассив_ДолгосрОбяз_Пред: 11.4% пропусков
# Пассив_ДолгосрОбяз_ПредПред: 21.5% пропусков
# Пассив_ДолгосрОбяз_ОтложНалОбяз_Отч: 32.6% пропусков
# Пассив_КраткосрОбяз_Пред: 1.8% пропусков
# Пассив_КраткосрОбяз_ПредПред: 5.3% пропусков
# Пассив_КраткосрОбяз_КредитЗадолж_Отч: 0.1% пропусков
# Пассив_КраткосрОбяз_КредитЗадолж_Пред: 2.0% пропусков
# Пассив_КраткосрОбяз_КредитЗадолж_ПредПред: 5.5% пропусков
# Выруч_Отч: 2.6% пропусков
# ПрибПрод_Отч: 0.8% пропусков
# ПрочДоход_Отч: 7.6% пропусков
# СовФинРез_Отч: 0.1% пропусков
# УпрРасход_Отч: 26.9% пропусков
# ПрочРасход_Отч: 0.5% пропусков
# СебестПрод_Отч: 5.5% пропусков
# ТекНалПриб_Отч: 17.5% пропусков
# ЧистПрибУб_Отч: 0.1% пропусков
# ПрибУбДоНал_Отч: 0.0% пропусков
# ОтложНалПриб_Отч: 30.8% пропусков
# ВаловаяПрибыль_Отч: 2.3% пропусков
# ДвижКап_Итог_Пред: 1.6% пропусков

# %% [markdown]
# Заполним оставшиеся пропуски нулями. Будем исходить из того, что у компаний, оставляющих данные столбцы пустыми соответсвующие показатели на текущий год отсутствуют (требований от ФНС самостоятельно заполнять нулями отсутствующие статьи - нет).

# %%
df.fillna(0, inplace=True)

# %% [markdown]
# Удалим компании, которые не заполняют активы/пассивы (если не заполнено что-то одно, то не заполнено и второе):

# %%
df[df['Актив_Отч'] == 0].shape
# Out:
# (0, 66)

# %%
df[df['Актив_Пред'] == 0].shape
# Out:
# (157, 66)

# %%
df[df['Актив_ПредПред'] == 0].shape
# Out:
# (464, 66)

# %%
df = df.drop(df[(df[preproc['cols_with_null']] == 0).any(axis=1)].index)

# %%
df.shape
# Out:
# (9536, 66)

# %% [markdown]
# Бинаризуем некоторые признаки:

# %%
df['ПрАудит'] = [1 if i==True else 0 for i in df['ПрАудит']]

# %%
if 'target' in df.columns:
    df['target'] = [0 if i=='2099-12-31' else 1 for i in df['target']]
else:
    print("Признака 'target' нет в DataFrame")
# Out:
# Признака 'target' нет в DataFrame

# %%
df
# Out:
#       ПрАудит  Актив_ОбА_ДебЗад_Отч  Актив_ОбА_ДебЗад_Пред  \
# 0           1              198477.0               157148.0
# 1           0              134095.0               138838.0
# 2           0                9569.0                 6316.0
# 3           0               91588.0               104941.0
# 4           1             1381628.0               216102.0
# ...       ...                   ...                    ...
# 9995        0               21240.0                15689.0
# 9996        1              233137.0               244945.0
# 9997        1                4762.0                 8036.0
# 9998        1               97573.0               138679.0
# 9999        0                9868.0                12038.0
#
#       Актив_ОбА_ДебЗад_ПредПред  Актив_ОбА_Запасы_Отч  Актив_ОбА_Запасы_Пред  \
# 0                      172958.0                219387               108123.0
# 1                      125797.0                 27525                33953.0
# 2                           0.0                  4145                  131.0
# 3                       93807.0                  4249                 4386.0
# 4                      217196.0                    39                    0.0
# ...                         ...                   ...                    ...
# 9995                    15949.0                     6                    6.0
# 9996                   326561.0                814115               747396.0
# 9997                     7119.0                 13125                 9252.0
# 9998                   337588.0                  2510                26341.0
# 9999                    10773.0                 37663                42052.0
#
#       Актив_ОбА_Запасы_ПредПред  Актив_ОбА_Отч  Актив_ОбА_ПрочОбА_Отч  \
# 0                       74581.0         498343                   2920
# 1                       34039.0         229725                   8407
# 2                           0.0          19589                   1882
# 3                      178013.0          95934                     53
# 4                          21.0        1586667                     74
# ...                         ...            ...                    ...
# 9995                     2548.0          58584                    335
# 9996                   497202.0        1130222                    323
# 9997                     4112.0          37110                    262
# 9998                    30525.0         650547                   2587
# 9999                    48933.0         111411                    404
#
#       Актив_ОбА_ПрочОбА_Пред  ...  ЧистПрибУб_Отч  ПрибУбДоНал_Отч  \
# 0                     6270.0  ...        235259.0         257840.0
# 1                    21565.0  ...          5950.0           7549.0
# 2                      760.0  ...          6340.0           8258.0
# 3                        0.0  ...          -942.0           1844.0
# 4                        0.0  ...        -53991.0         -55670.0
# ...                      ...  ...             ...              ...
# 9995                   342.0  ...          6439.0           6351.0
# 9996                   333.0  ...         10007.0          12375.0
# 9997                 29679.0  ...        -83930.0        -104444.0
# 9998                  2484.0  ...         54662.0          62009.0
# 9999                   282.0  ...         51354.0          66300.0
#
#       ОтложНалПриб_Отч  ВаловаяПрибыль_Отч  ДвижКап_Итог_Пред  \
# 0               -883.0            574079.0           105262.0
# 1              -1597.0               663.0            90936.0
# 2                  0.0             33993.0              677.0
# 3               -427.0              9469.0          -959604.0
# 4               1679.0              -809.0           -54827.0
# ...                ...                 ...                ...
# 9995            2406.0             26916.0            42227.0
# 9996            1042.0            409961.0            32424.0
# 9997           20514.0            -71999.0           305706.0
# 9998           -7347.0             26540.0           420531.0
# 9999               0.0            136969.0            98830.0
#
#       ДвижКап_Итог_Отч  ДвижКап_Итог_ПредПред  ЧистАктив_Отч  ЧистАктив_Пред  \
# 0               340521                   2412         340521          105261
# 1                96885                  91032          96885           90936
# 2                 6791                     10           6791             677
# 3              -949173                -953981        -949173         -959604
# 4             -2485153                 -62163       -2485153          -54827
# ...                ...                    ...            ...             ...
# 9995             48667                  38872          48667           42227
# 9996             36161                  19231          36161           32424
# 9997            319776                 250718         319776          305706
# 9998            365065                 387240         365065          420531
# 9999            109241                  97798              0               0
#
#       ЧистАктив_ПредПред
# 0                   2412
# 1                  91032
# 2                     10
# 3                -953981
# 4                 -62163
# ...                  ...
# 9995               38872
# 9996               19231
# 9997              250718
# 9998              387240
# 9999                   0
#
# [9536 rows x 66 columns]

# %%
df.to_csv(evaluate['predict_path'],
          index=False)
